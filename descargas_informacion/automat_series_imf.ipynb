# %% [markdown]
# # Automatización de descarga de datos del Fondo Monetario Internacional
#
# Esta función busca interactuar con la interfaz de programación de aplicaciones (API en inglés) del Fondo Monetario Internacional. Para ello, requiere los siguientes insumos:
#
# - La serie o identificador con el que el Fondo Monetario Internacional identifica al indicador
# - El año de inicio de consulta
# - El año de fin de consulta
#
# La lista de indicadores que pone el FMI a disposición del público se encuentra al final de este documento.

# %%
import requests
import pandas as pd
import numpy as np

# %%
def descargar_imf(serie,fecha_inicio,fecha_fin,paises='All'):
    """
    Donde:
    - serie: identificador del FMI para el indicador
    - fecha inicio: año de inicio de la consulta
    - fecha fin: año de fin de la consulta

    """
    fecha_inicio=int(fecha_inicio)
    fecha_fin=int(fecha_fin)
    periodos=list(range(fecha_inicio,fecha_fin+1,1))
    periodos=str(periodos).strip("[]").replace(" ","")
    url1='https://www.imf.org/external/datamapper/api/v1/'+serie+'?periods='+periodos
    response = requests.get(url1)
    status=response.status_code
    raw_data = response.json()
    titulo=raw_data['values'].keys()
    valores=raw_data['values'][serie]
    return pd.DataFrame(valores)

descargar_imf('NGDP_RPCH','2012','2020')
# Out:
#       DZA   ATG   ABW  AZE  BHR   BRB  BLR   BLZ  BEN  BIH  ...  EUQ  MEQ  \
# 2012  3.4   3.4  -1.0  2.2  3.7  -0.4  1.6   3.9  4.8 -0.7  ...  0.4  3.8
# 2013  2.8  -0.6   6.4  5.8  5.4  -1.4  1.0   4.5  7.2  2.4  ...  0.5  2.9
# 2014  3.8   3.8   0.0  2.8  4.4  -0.1  1.7   4.1  6.4  1.1  ...  1.6  3.7
# 2015  3.7   3.8   3.6  1.0  2.5   2.4 -3.8   3.4  1.8  4.3  ...  1.6  2.5
# 2016  3.2   5.5   2.1 -3.1  3.6   2.5 -2.5   0.1  3.3  3.2  ...  1.8  5.4
# 2017  1.4   3.1   5.5  0.2  4.3   0.5  2.5  -1.7  5.7  3.2  ...  2.8  0.6
# 2018  1.2   6.9   5.3  1.5  2.1  -0.6  3.1   1.1  6.7  3.8  ...  2.3  1.5
# 2019  1.0   4.9   0.6  2.5  2.2  -0.5  1.4   4.5  6.9  2.9  ...  2.0  0.4
# 2020 -5.1 -20.2 -18.6 -4.2 -4.6 -13.3 -0.7 -13.4  3.8 -3.0  ... -5.5 -3.6
#
#       NAQ  NMQ   PIQ  SMQ  SAQ  SEQ  WEQ  WHQ
# 2012  9.9  2.4   3.4  2.7  5.4  6.1 -0.4  2.5
# 2013  1.8  1.8   3.9  3.3  6.0  5.1  0.2  2.2
# 2014  1.7  2.4  10.5  0.5  6.9  4.8  1.7  2.0
# 2015  3.7  2.6   5.7 -1.1  7.3  4.9  2.2  1.8
# 2016  3.1  1.7   4.8 -2.4  7.6  5.1  1.9  0.9
# 2017  4.6  2.3   3.9  0.8  6.6  5.4  2.6  2.0
# 2018  4.2  2.8   0.9  0.5  6.4  5.3  1.8  2.4
# 2019  2.9  2.0   3.0 -0.1  3.9  4.7  1.6  1.6
# 2020 -1.8 -3.4  -6.2 -6.3 -4.3 -3.1 -6.6 -4.1
#
# [9 rows x 227 columns]

# %% [markdown]
# # Glosario de identificadores del FMI contenidos en el API y buscador
#
# El glosario de identificadores con la que el FMI etiqueta a los etiquetadores está bajo el diccionario "glosario"

# %%
url_indic='https://www.imf.org/external/datamapper/api/v1/indicators'
response = requests.get(url_indic)
status=response.status_code
raw = response.json()
T=2
glosario={}
for i in raw['indicators'].keys():
    titulos=i
    desc1=raw['indicators'][i]['label']
    glosario.update({i:desc1})
print('número de indicadores en el diccionario:',len(glosario.keys()))
glosario
# Out:
# número de indicadores en el diccionario: 128
# {'NGDP_RPCH': 'Real GDP growth',
#  'NGDPD': 'GDP, current prices',
#  'NGDPDPC': 'GDP per capita, current prices\n',
#  'PPPGDP': 'GDP, current prices',
#  'PPPPC': 'GDP per capita, current prices',
#  'PPPSH': 'GDP based on PPP, share of world',
#  'PPPEX': 'Implied PPP conversion rate',
#  'PCPIPCH': 'Inflation rate, average consumer prices',
#  'PCPIEPCH': 'Inflation rate, end of period consumer prices',
#  'LP': 'Population',
#  'BCA': 'Current account balance\nU.S. dollars',
#  'BCA_NGDPD': 'Current account balance, percent of GDP',
#  '': None,
#  'LUR': 'Unemployment rate',
#  'GGXCNL_NGDP': 'General government net lending/borrowing',
#  'GGXWDG_NGDP': 'General government gross debt',
#  'rev': 'Government revenue, percent of GDP',
#  'exp': 'Government expenditure, percent of GDP',
#  'prim_exp': 'Government primary expenditure, percent of GDP',
#  'ie': 'Interest paid on public debt, percent of GDP',
#  'pb': 'Government primary balance, percent of GDP',
#  'd': 'Gross public debt, percent of GDP',
#  'rgc': 'Real GDP growth rate, percent',
#  'rltir': 'Real long term government bond yield, percent',
#  'extensive': 'Extensive Margin',
#  'intensive': 'Intensive Margin',
#  'total_theil': 'Export Diversification Index',
#  'SITC1_0': 'Food and live animals',
#  'SITC1_1': 'Beverages and tobacco',
#  'SITC1_2': 'Crude materials, inedible, except fuels',
#  'SITC1_3': 'Mineral fuels, lubricants and related materials',
#  'SITC1_4': 'Animal and vegetable oils and fats',
#  'SITC1_5': 'Chemicals',
#  'SITC1_6': 'Manufact goods classified chiefly by material',
#  'SITC1_7': 'Machinery and transport equipment',
#  'SITC1_8': 'Miscellaneous manufactured articles',
#  'SITC1_9': 'Commodity & transactions not classified accord to kind',
#  'SITC1_total': 'Export Quality Index',
#  'DirectAbroad': 'Direct Investment Abroad',
#  'DirectIn': 'Direct Investment In Country',
#  'PrivInexDI': 'Private Inflows excluding Direct Investment',
#  'PrivInexDIGDP': 'Private Inflows excluding Direct Investment (% of GDP)',
#  'PrivOutexDI': 'Private Outflows excluding Direct Investment',
#  'PrivOutexDIGDP': 'Private Outflows excluding Direct Investment (% of GDP)',
#  'Portfa': 'Portfolio Investment Assets',
#  'Portfl': 'Portfolio Investment Liabilities',
#  'EquityA': 'Equity Securities Assets',
#  'EquityL': 'Equity Securities Liabilities',
#  'DebtA': 'Debt Securities Assets',
#  'DebtL': 'Debt Securities Liabilities',
#  'OtherGov': 'Proxy for Official Other Investment Liabilities',
#  'OtherA': 'Other Investment Assets',
#  'OtherL': 'Other Investment Liabilities',
#  'Deriv': 'Financial Derivatives',
#  'DebtForg': 'Debt Forgiveness',
#  'GDP': 'Nominal GDP',
#  'ka_new': 'Overall Openness Index (all asset categories)',
#  'ka_in': 'Openness of Capital Inflows Index  (1=fully liberalized)',
#  'ka_out': 'Openness of Capital Outflows Index   (1=fully liberalized)',
#  'FM_ka': 'Financial Market Openness Index (equity, bond, money market, collective investment, derivates) 1=fully liberalized',
#  'Nonres_ka': 'Nonresident Openness Index (1=fully liberalized)',
#  'Res_ka': 'Resident Openness Index (1=fully liberalized)',
#  'Ka_eq': 'Equity openness index (1=fully liberalized)',
#  'Ka_bo': 'Bond openness index (1=fully liberalized)',
#  'Ka_mm': 'Money market openness index (1=fully liberalized)',
#  'Ka_ci': 'Collective investment openness index (1=fully liberalized)',
#  'Ka_dr': 'Derivative investment openness index (1=fully liberalized)',
#  'Ka_cc': 'Commercial credit openness index (1=fully liberalized)',
#  'Ka_fc': 'Financial credit openness index (1=fully liberalized)',
#  'Ka_gu': 'Guarantee openness index (1=fully liberalized)',
#  'Ka_di': 'Direct investment openness index (1=fully liberalized)',
#  'ka_ldi': 'Direct investment liquidation openness index (1=fully liberalized)',
#  'ka_ret': 'Real estate capital transaction openness index (1=fully liberalized)',
#  'ka_pct': 'Personal capital transaction openness index (1=fully liberalized)',
#  'Reserves_ARA': 'Ratio of reserve/ARA metric ',
#  'Reserves_M2': 'Reserves/Broad Money',
#  'Reserves_STD': 'Reserves/Short-term Debt (STD)',
#  'Reserves_M': 'Reserve/(Import/12) ',
#  'GRB_dummy': 'Gender Budgeting Indicator',
#  'GDI_TC': 'Gender Development Index (GDI) Time Consistent',
#  'GII_TC': 'Gender Inequality Index (GII) Time Consistent',
#  'DEBT1': 'DEBT',
#  'Privatedebt_all': 'Private debt, all instruments',
#  'HH_ALL': 'Household debt, all instruments',
#  'NFC_ALL': 'Nonfinancial corporate debt, all instruments',
#  'PVD_LS': 'Private debt, loans and debt securities',
#  'HH_LS': 'Household debt, loans and debt securities',
#  'NFC_LS': 'Nonfinancial corporate debt, loans and debt securities',
#  'PS_DEBT_GDP': 'Public Sector Debt',
#  'NFPS_DEBT_GDP': 'Nonfinancial Public Sector Debt',
#  'GG_DEBT_GDP': 'General Government Debt',
#  'CG_DEBT_GDP': 'Central Government Debt',
#  'GGXCNL_G01_GDP_PT': 'Net lending/borrowing (also referred as overall balance)',
#  'GGXONLB_G01_GDP_PT': 'Primary net lending/borrowing (also referred as primary balance)',
#  'GGCB_G01_PGDP_PT': 'Cyclically adjusted balance',
#  'GGCBP_G01_PGDP_PT': 'Cyclically adjusted primary balance',
#  'GGR_G01_GDP_PT': 'Revenue',
#  'G_X_G01_GDP_PT': 'Expenditure',
#  'G_XWDG_G01_GDP_PT': 'Gross debt position',
#  'GGXWDN_G01_GDP_PT': 'Net debt',
#  'NGDP_R_PCH': 'Real GDP Growth',
#  'NGDPXO_RPCH': 'Real Non-Oil GDP Growth',
#  'NGDPRPC_PCH': 'Real Per Capita GDP Growth',
#  'NI_GDP': 'Total Investment (% of GDP)',
#  'NGS_GDP': 'Gross National Savings (% of GDP)',
#  'GGXCNL_GDP': 'Overall Fiscal Balance, Including Grants (% of GDP)',
#  'GGXCNLXG_GDP': 'Overall Fiscal Balance, Excluding Grants (% of GDP)',
#  'GGRXG_GDP': 'Government Revenue, Excluding Grants (% of GDP)',
#  'GGX_GDP': 'Government Expenditure (% of GDP)',
#  'GGXWDG_GDP': 'Government Debt (% of GDP)',
#  'FMB_GDP': 'Broad Money (% of GDP)',
#  'FDSAOP_PCH': 'Claims on Nonfinancial Private Sector (%)',
#  'FDSAOP_GDP': 'Claims on Nonfinancial Private Sector (% of GDP)',
#  'FMB_PCH': 'Broad Money Growth',
#  'BX_GDP': 'Exports of Goods and Services (% of GDP)',
#  'BCA_GDP': 'External Current Account, Incl.Grants (% of GDP)',
#  'BM_GDP': 'Imports of Goods and Services (% of GDP)',
#  'BT_GDP': 'Trade Balance (% of GDP)',
#  'BFD_GDP': 'Net Foreign Direct Investment (% of GDP)',
#  'BRASS_MI': 'Reserves (Months of Imports) ',
#  'EREER': 'Real Effective Exchange Rates (2010=100)',
#  'ENEER': 'Nominal Effective Exchange Rates (2010=100)',
#  'DG_GDP': 'External Debt, Official Debt, Debtor Based (% of GDP)',
#  'PCPI_PCH': 'Consumer Prices, Average (Annual % Change)',
#  'PCPIE_PCH': 'Consumer Prices, End of Period (Annual % Change)',
#  'TTT': 'Terms of Trade (Index, 2010 = 100)',
#  'FR_ind': 'Fiscal Rule Indicator',
#  'FC_dummy': 'Fiscal Council Indicator'}

# %%
check1=[]
for k,v in glosario.items():
    i=0
    if glosario[k] != None:
        check1.append(False)
    else:
        check1.append(True)
    i=i+1
index1=check1.index(True)
index1
# Out:
# 12
